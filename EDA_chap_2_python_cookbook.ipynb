# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabahat-Tufail/EDA/blob/main/EDA_chap_2_python_cookbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load DATA SET

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-01976911-cf6b-4bd4-9f35-0ac2d194f25f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01976911-cf6b-4bd4-9f35-0ac2d194f25f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("titanic (1).csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df=df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns')

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# Fare        float64
# dtype: object

# %%
df.shape
# Out:
# (891, 5)

# %% [markdown]
# ## Average number of people survived based on gender
# 74% of females survived
#
# 19% of males survived

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df2=pd.read_csv("titanic.csv")
df = pd.read_csv("titanic (1).csv")

# %% [markdown]
# Inspecting Shape of both data sets

# %%
print(df.shape)
print(df2.shape)
# Out:
# (891, 12)
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Appending
# In my dataset, I used pd.concat([df, df2]) to combine two DataFrames by appending the rows of df2 to df.
# This helped me create one larger dataset containing all the records from both files.

# %%
append =pd.concat([df, df2])

# %%
append.shape
# Out:
# (1782, 12)

# %%
append.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### I used .concat() to add the new rows from df2 at the bottom of the existing data in df, like adding more pages to the end of a register.
#
# ### It helped me combine the data into one DataFrame so I could analyze everything together.

# %% [markdown]
# # Concatenating two data sets

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare'], dtype='object')

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2=df2.drop(['Survived','Pclass','Sex','Age','Fare'],axis='columns')

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
concatenated_data=pd.concat([df,df2],axis=1)

# %%
concatenated_data.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare  PassengerId  \
# 0         0       3    male  22.0   7.2500            1
# 1         1       1  female  38.0  71.2833            2
# 2         1       3  female  26.0   7.9250            3
# 3         1       1  female  35.0  53.1000            4
# 4         0       3    male  35.0   8.0500            5
#
#                                                 Name  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 2                             Heikkinen, Miss. Laina      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# 4                           Allen, Mr. William Henry      0      0
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
concatenated_data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare', 'PassengerId', 'Name',
#        'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# I had two sets of information about Titanic passengers.
# One file had basic details like whether they survived, their gender, class, age, and fare.
# The second file had those same columns again but also included more information like their names, tickets, and cabin numbers.
#
# To avoid repeating the same columns, I removed the duplicate ones from the second file.
#
# Then I joined both files side by side, so now for every passenger, I have all the information in one single row — from survival status to personal details.
#
# This is called column-wise concatenation, where we attach more columns to the same people

# %% [markdown]
# # MERGING TWO DATA SETS

# %%
df4=df2

# %%
df4=df4.drop(['SibSp','Parch'],axis='columns')

# %%
df4.columns
# Out:
# Index(['PassengerId', 'Name'], dtype='object')

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare'], dtype='object')

# %%
df['PassengerId'] = df2['PassengerId']

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare', 'PassengerId'], dtype='object')

# %%
df=df.drop(['Pclass','Fare','Sex'],axis='columns')

# %%
df.head()
# Out:
#    Survived   Age  PassengerId
# 0         0  22.0            1
# 1         1  38.0            2
# 2         1  26.0            3
# 3         1  35.0            4
# 4         0  35.0            5

# %%
df4.head()
# Out:
#    PassengerId                                               Name
# 0            1                            Braund, Mr. Owen Harris
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3                             Heikkinen, Miss. Laina
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5                           Allen, Mr. William Henry

# %%
merged_data=pd.merge(df,df4,on='PassengerId')

# %%
merged_data.head()
# Out:
#    Survived   Age  PassengerId  \
# 0         0  22.0            1
# 1         1  38.0            2
# 2         1  26.0            3
# 3         1  35.0            4
# 4         0  35.0            5
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %% [markdown]
# # OUTPUT
# I had two datasets, both containing a common column called PassengerId. I used the merge() function to join them based on this ID. This allowed me to combine matching rows from both datasets into one, so now each row in the new dataset has complete information from both sources.

# %% [markdown]
# ## Sorting passengers based on age

# %%
sorted_data=df.sort_values(by='Age',ascending=False)

# %%
sorted_data[['PassengerId','Age']]
# Out:
#      PassengerId   Age
# 630          631  80.0
# 851          852  74.0
# 493          494  71.0
# 96            97  71.0
# 116          117  70.5
# ..           ...   ...
# 859          860   NaN
# 863          864   NaN
# 868          869   NaN
# 878          879   NaN
# 888          889   NaN
#
# [891 rows x 2 columns]

# %% [markdown]
# I sorted my dataset by the `Age` column in descending order using `sort_values()`. This helped me arrange the passengers from oldest to youngest. Then I displayed only the `PassengerId` and `Age` columns to clearly see the sorted age list.

# %% [markdown]
# # Categorising the age into child,teen ,adult

# %%
df['Stage']=pd.cut(df['Age'],bins=[0,12,19,100],labels=['Child','Teen','Adult'])

# %%
df[['Age','Stage']].head(20)
# Out:
#      Age  Stage
# 0   22.0  Adult
# 1   38.0  Adult
# 2   26.0  Adult
# 3   35.0  Adult
# 4   35.0  Adult
# 5    NaN    NaN
# 6   54.0  Adult
# 7    2.0  Child
# 8   27.0  Adult
# 9   14.0   Teen
# 10   4.0  Child
# 11  58.0  Adult
# 12  20.0  Adult
# 13  39.0  Adult
# 14  14.0   Teen
# 15  55.0  Adult
# 16   2.0  Child
# 17   NaN    NaN
# 18  31.0  Adult
# 19   NaN    NaN

# %%
df['Stage']=pd.cut(df['Age'],bins=3,labels=['Child','Teen','Adult'])

# %%
df[['Age','Stage']].head(20)
# Out:
#      Age  Stage
# 0   22.0  Child
# 1   38.0   Teen
# 2   26.0  Child
# 3   35.0   Teen
# 4   35.0   Teen
# 5    NaN    NaN
# 6   54.0  Adult
# 7    2.0  Child
# 8   27.0   Teen
# 9   14.0  Child
# 10   4.0  Child
# 11  58.0  Adult
# 12  20.0  Child
# 13  39.0   Teen
# 14  14.0  Child
# 15  55.0  Adult
# 16   2.0  Child
# 17   NaN    NaN
# 18  31.0   Teen
# 19   NaN    NaN

# %% [markdown]
# I categorized the passengers based on their age into three groups—Child, Teen, and Adult—using the pd.cut() function. I created a new column called Stage in my dataset, where each person’s age was assigned a label according to defined age ranges (0–12 as Child, 13–19 as Teen, and 20–100 as Adult). This helped me simplify the analysis by grouping ages into broader categories.

# %% [markdown]
# # Removing Duplicates
# I removed duplicate rows from my dataset using the `drop_duplicates()` function and stored the result in a new DataFrame called `df_duplicates`. After checking the shape of both the original and the new DataFrame, I found that they have the same number of rows (891), which means there were no duplicate entries to begin with.

# %%
df_duplicates=df.drop_duplicates()

# %%
df_duplicates
# Out:
#      Survived   Age  PassengerId  Stage
# 0           0  22.0            1  Child
# 1           1  38.0            2   Teen
# 2           1  26.0            3  Child
# 3           1  35.0            4   Teen
# 4           0  35.0            5   Teen
# ..        ...   ...          ...    ...
# 886         0  27.0          887   Teen
# 887         1  19.0          888  Child
# 888         0   NaN          889    NaN
# 889         1  26.0          890  Child
# 890         0  32.0          891   Teen
#
# [891 rows x 4 columns]

# %%
df.shape
# Out:
# (891, 4)

# %%
df_duplicates.shape
# Out:
# (891, 4)

# %% [markdown]
# # Deleting specific rows and column

# %%
df=df[:5]

# %%
df.head()
# Out:
#    Survived   Age  PassengerId  Stage
# 0         0  22.0            1  Child
# 1         1  38.0            2   Teen
# 2         1  26.0            3  Child
# 3         1  35.0            4   Teen
# 4         0  35.0            5   Teen

# %% [markdown]
# to delete index 2
# Now in output we can see row number 2 and 3 are disappered from data set

# %%
df=df.drop(labels=[2],axis = 0)

# %%
df.head()
# Out:
#    Survived   Age  PassengerId  Stage
# 0         0  22.0            1  Child
# 1         1  38.0            2   Teen
# 4         0  35.0            5   Teen

# %% [markdown]
# ### Delete single column
# In output we can cleraly observe that coumn named age is missing

# %%
df=df.drop(labels=['Age'],axis = 1)

# %%
df.head()
# Out:
#    Survived  PassengerId  Stage
# 0         0            1  Child
# 1         1            2   Teen
# 4         0            5   Teen

# %% [markdown]
# # Changing Data Fromat

# %%
df5 = pd.read_csv("titanic (1).csv")

# %%
df5=df5.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns')

# %%
df5.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare'], dtype='object')

# %%
df5.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
df5['Fare']=df5['Fare'].astype(int)

# %%
df5['Fare'].head()
# Out:
# 0     7
# 1    71
# 2     7
# 3    53
# 4     8
# Name: Fare, dtype: int64

# %% [markdown]
# We can clearly observe that fare first was float data type but I updated Fare into int.

# %% [markdown]
# # Replacing Data

# %%
df5.head()
# Out:
#    Survived  Pclass     Sex   Age  Fare
# 0         0       3    male  22.0     7
# 1         1       1  female  38.0    71
# 2         1       3  female  26.0     7
# 3         1       1  female  35.0    53
# 4         0       3    male  35.0     8

# %% [markdown]
# Replacing binarires in Survived column (0,1) to Living and Died

# %%
df5['Survived_replaced']=df5['Survived'].replace([0,1],['Died','Living'])

# %%
df5[['Survived','Survived_replaced']].head()
# Out:
#    Survived Survived_replaced
# 0         0              Died
# 1         1            Living
# 2         1            Living
# 3         1            Living
# 4         0              Died

# %% [markdown]
# # Dealing with missing values

# %%
df.isnull().sum()
# Out:
# Survived       0
# PassengerId    0
# Stage          0
# dtype: int64

# %% [markdown]
# means there are no missing (NaN) values in these columns — everything is complete.

# %%
df5.shape
# Out:
# (891, 6)

# %%
df5_withoutna=df5.dropna()

# %%
df5_withoutna.shape
# Out:
# (714, 6)

# %%
Initially, the dataset had 891 rows and 6 columns. After using `dropna()`, all rows with missing values were removed, and the dataset was reduced to 714 rows while still having 6 columns. This means 177 rows had missing values and were deleted, so now the data is clean and has no missing values left.
